# %% [markdown]
# # Data Preparation and Cleaning

# %%
#import libraries
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
#load dataset
tcr_df = pd.read_csv('thyroid_cancer_risk_data.csv')
tcr_df
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 0                1   66    Male   Russia       Caucasian             No
# 1                2   29    Male  Germany        Hispanic             No
# 2                3   86    Male  Nigeria       Caucasian             No
# 3                4   75  Female    India           Asian             No
# 4                5   35  Female  Germany         African            Yes
# ...            ...  ...     ...      ...             ...            ...
# 212686      212687   58  Female    India           Asian             No
# 212687      212688   89    Male    Japan  Middle Eastern             No
# 212688      212689   72  Female  Nigeria        Hispanic             No
# 212689      212690   85  Female   Brazil  Middle Eastern             No
# 212690      212691   46  Female    Japan  Middle Eastern             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# ...

# %%
tcr_df.shape
# Out:
# (212691, 17)

# %%
tcr_df.head()
# Out:
#    Patient_ID  Age  Gender  Country  Ethnicity Family_History  \
# 0           1   66    Male   Russia  Caucasian             No
# 1           2   29    Male  Germany   Hispanic             No
# 2           3   86    Male  Nigeria  Caucasian             No
# 3           4   75  Female    India      Asian             No
# 4           5   35  Female  Germany    African            Yes
#
#   Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  TSH_Level  \
# 0                Yes                No      No      No       No       9.37
# 1                Yes                No      No      No       No       1.83
# 2                 No                No      No      No       No       6.26
# 3                 No                No      No      No       No       4.10
# 4                Yes                No      No      No       No       9.10
#
#    T3_Level  T4_Level  Nodule_Size Thyroid_Cancer_Risk Diagnosis
# 0      1.67      6.16         1.08                 Low    Benign
# ...

# %%
MSFT_df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 9795  2025-01-28  434.600006  448.380005  431.380005  447.200012  447.200012
# 9796  2025-01-29  446.690002  446.880005  440.399994  442.329987  442.329987
# 9797  2025-01-30  418.769989  422.859985  413.160004  414.989990  414.989990
# 9798  2025-01-31  418.980011  420.690002  414.910004  415.059998  415.059998
# 9799  2025-02-03  411.600006  415.410004  408.660004  410.920013  410.920013
#
#         Volume
# 9795  23491700
# 9796  23581400
# 9797  54586300
# 9798  34223400
# 9799  25580600

# %%
tcr_df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Country', 'Ethnicity', 'Family_History',
#        'Radiation_Exposure', 'Iodine_Deficiency', 'Smoking', 'Obesity',
#        'Diabetes', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size',
#        'Thyroid_Cancer_Risk', 'Diagnosis'],
#       dtype='object')

# %%
tcr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212691 entries, 0 to 212690
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Patient_ID           212691 non-null  int64
#  1   Age                  212691 non-null  int64
#  2   Gender               212691 non-null  object
#  3   Country              212691 non-null  object
#  4   Ethnicity            212691 non-null  object
#  5   Family_History       212691 non-null  object
#  6   Radiation_Exposure   212691 non-null  object
#  7   Iodine_Deficiency    212691 non-null  object
#  8   Smoking              212691 non-null  object
#  9   Obesity              212691 non-null  object
#  10  Diabetes             212691 non-null  object
#  11  TSH_Level            212691 non-null  float64
#  12  T3_Level             212691 non-null  float64
#  13  T4_Level             212691 non-null  float64
# ...

# %%
tcr_df.describe()
# Out:
#          Patient_ID            Age      TSH_Level       T3_Level  \
# count  212691.00000  212691.000000  212691.000000  212691.000000
# mean   106346.00000      51.918497       5.045102       2.001727
# std     61398.74739      21.632815       2.860264       0.866248
# min         1.00000      15.000000       0.100000       0.500000
# 25%     53173.50000      33.000000       2.570000       1.250000
# 50%    106346.00000      52.000000       5.040000       2.000000
# 75%    159518.50000      71.000000       7.520000       2.750000
# max    212691.00000      89.000000      10.000000       3.500000
#
#             T4_Level    Nodule_Size
# count  212691.000000  212691.000000
# mean        8.246204       2.503403
# std         2.164188       1.444631
# min         4.500000       0.000000
# 25%         6.370000       1.250000
# 50%         8.240000       2.510000
# 75%        10.120000       3.760000
# max        12.000000       5.000000

# %%
tcr_df.describe(include = 'object')
# Out:
#         Gender Country  Ethnicity Family_History Radiation_Exposure  \
# count   212691  212691     212691         212691             212691
# unique       2      10          5              2                  2
# top     Female   India  Caucasian             No                 No
# freq    127527   42496      63669         148866             180831
#
#        Iodine_Deficiency Smoking Obesity Diabetes Thyroid_Cancer_Risk  \
# count             212691  212691  212691   212691              212691
# unique                 2       2       2        2                   3
# top                   No      No      No       No                 Low
# freq              159673  170260  148805   170098              108388
#
#        Diagnosis
# count     212691
# unique         2
# top       Benign
# freq      163196

# %%
tcr_df.Patient_ID=='1'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 212686    False
# 212687    False
# 212688    False
# 212689    False
# 212690    False
# Name: Patient_ID, Length: 212691, dtype: bool

# %%
data = tcr_df.loc[tcr_df.Patient_ID=='1'] 
data
# Out:
# Empty DataFrame
# Columns: [Patient_ID, Age, Gender, Country, Ethnicity, Family_History, Radiation_Exposure, Iodine_Deficiency, Smoking, Obesity, Diabetes, TSH_Level, T3_Level, T4_Level, Nodule_Size, Thyroid_Cancer_Risk, Diagnosis]
# Index: []

# %%
tcr_df = tcr_df.drop_duplicates()

# %%
#Finding Columns with Missing Values
tcr_df.isna().any()
# Out:
# Patient_ID             False
# Age                    False
# Gender                 False
# Country                False
# Ethnicity              False
# Family_History         False
# Radiation_Exposure     False
# Iodine_Deficiency      False
# Smoking                False
# Obesity                False
# Diabetes               False
# TSH_Level              False
# T3_Level               False
# T4_Level               False
# Nodule_Size            False
# Thyroid_Cancer_Risk    False
# Diagnosis              False
# dtype: bool

# %%
tcr_df.shape
# Out:
# (212691, 17)

# %%
for i in range(0,MSFT_df.shape[0]):
  tcr_df['Diabetes'][i] = tcr_df['Diabetes'][i].replace(',', '')

tcr_df['Diabetes']
# Out:
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
#          ...
# 212686     No
# 212687     No
# 212688    Yes
# 212689    Yes
# 212690     No
# Name: Diabetes, Length: 212691, dtype: object

# %%
tcr_df['Diabetes'] = pd.to_numeric(tcr_df['Diabetes'], errors='coerce', downcast="integer")

# %%
tcr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212691 entries, 0 to 212690
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Patient_ID           212691 non-null  int64
#  1   Age                  212691 non-null  int64
#  2   Gender               212691 non-null  object
#  3   Country              212691 non-null  object
#  4   Ethnicity            212691 non-null  object
#  5   Family_History       212691 non-null  object
#  6   Radiation_Exposure   212691 non-null  object
#  7   Iodine_Deficiency    212691 non-null  object
#  8   Smoking              212691 non-null  object
#  9   Obesity              212691 non-null  object
#  10  Diabetes             0 non-null       float64
#  11  TSH_Level            212691 non-null  float64
#  12  T3_Level             212691 non-null  float64
#  13  T4_Level             212691 non-null  float64
# ...

# %%
tcr_df.isnull().sum()
# Out:
# Patient_ID                  0
# Age                         0
# Gender                      0
# Country                     0
# Ethnicity                   0
# Family_History              0
# Radiation_Exposure          0
# Iodine_Deficiency           0
# Smoking                     0
# Obesity                     0
# Diabetes               212691
# TSH_Level                   0
# T3_Level                    0
# T4_Level                    0
# Nodule_Size                 0
# Thyroid_Cancer_Risk         0
# Diagnosis                   0
# dtype: int64

# %%
tcr_df['Diabetes'] = tcr_df['Diabetes'].replace(np.nan, 0)

# %%
#Again describe
tcr_df.describe()
# Out:
#          Patient_ID            Age  Diabetes      TSH_Level       T3_Level  \
# count  212691.00000  212691.000000  212691.0  212691.000000  212691.000000
# mean   106346.00000      51.918497       0.0       5.045102       2.001727
# std     61398.74739      21.632815       0.0       2.860264       0.866248
# min         1.00000      15.000000       0.0       0.100000       0.500000
# 25%     53173.50000      33.000000       0.0       2.570000       1.250000
# 50%    106346.00000      52.000000       0.0       5.040000       2.000000
# 75%    159518.50000      71.000000       0.0       7.520000       2.750000
# max    212691.00000      89.000000       0.0      10.000000       3.500000
#
#             T4_Level    Nodule_Size
# count  212691.000000  212691.000000
# mean        8.246204       2.503403
# std         2.164188       1.444631
# min         4.500000       0.000000
# 25%         6.370000       1.250000
# 50%         8.240000       2.510000
# ...

# %% [markdown]
# # Exploratory Analysis and Visualization

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
tcr_df
# Out:
#         Patient_ID  Age  Gender  Country       Ethnicity Family_History  \
# 0                1   66    Male   Russia       Caucasian             No
# 1                2   29    Male  Germany        Hispanic             No
# 2                3   86    Male  Nigeria       Caucasian             No
# 3                4   75  Female    India           Asian             No
# 4                5   35  Female  Germany         African            Yes
# ...            ...  ...     ...      ...             ...            ...
# 212686      212687   58  Female    India           Asian             No
# 212687      212688   89    Male    Japan  Middle Eastern             No
# 212688      212689   72  Female  Nigeria        Hispanic             No
# 212689      212690   85  Female   Brazil  Middle Eastern             No
# 212690      212691   46  Female    Japan  Middle Eastern             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity  Diabetes  \
# ...

# %% [markdown]
# # Let's do unvariate analysis

# %%
# Countplot
plt.figure(figsize=(20, 5)) 
sns.set(style='dark') 

sns.countplot(x=df['Country'].sort_values(ascending=False), palette="coolwarm")

plt.xticks(rotation=90)  
plt.title("Patient Distribution by Country")  
plt.xlabel("Country")  
plt.ylabel("Count")  

plt.show()

# %% [markdown]
# # Histogram:TSH level vs Frequency

# %%
plt.figure(figsize=(10, 7))  
sns.set(style='dark')  

sns.histplot(data=df, x='TSH_Level', color='indigo', binwidth=0.5)

plt.title("Distribution of TSH Levels")  
plt.xlabel("TSH Level") 
plt.ylabel("Frequency")  

plt.show()

# %% [markdown]
# # Count plot

# %%
plt.figure(figsize=(16, 6)) 
sns.set(style='dark') 

sns.countplot(x='Thyroid_Cancer_Risk', data=df, palette="viridis")

plt.xticks(rotation=90)  
plt.title("Distribution of Thyroid Cancer Risk Levels")  
plt.xlabel("Thyroid Cancer Risk")  
plt.ylabel("Count")  

plt.show()

# %%
high_risk_patients = df.loc[df['Thyroid_Cancer_Risk'] == 'High']
high_risk_patients
# Out:
#         Patient_ID  Age  Gender      Country Ethnicity Family_History  \
# 4                5   35  Female      Germany   African            Yes
# 6                7   89  Female  South Korea     Asian            Yes
# 8                9   17  Female       Russia   African             No
# 10              11   67    Male      Nigeria   African             No
# 12              13   44    Male  South Korea     Asian            Yes
# ...            ...  ...     ...          ...       ...            ...
# 212642      212643   63    Male        India     Asian            Yes
# 212645      212646   49  Female        India     Asian             No
# 212649      212650   74  Female       Brazil   African             No
# 212664      212665   29    Male        India     Asian             No
# 212683      212684   57    Male        India   African             No
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# ...

# %% [markdown]
# # Histogram

# %%
high_risk_patients = df.loc[df['Thyroid_Cancer_Risk'] == 'High']

plt.figure(figsize=(20, 6))  
sns.set(style='dark')  

sns.histplot(high_risk_patients['TSH_Level'], color='r', bins=50, kde=True)

plt.title("Distribution of TSH Levels in High-Risk Thyroid Cancer Patients")  
plt.xlabel("TSH Level")  
plt.ylabel("Density") 

plt.show()

# %% [markdown]
# # Scatter plot

# %%
subset_df = df.head(200)

plt.figure(figsize=(10, 5))  
sns.set(style='dark')  

sns.scatterplot(x=subset_df['TSH_Level'], y=subset_df['Nodule_Size'], hue=subset_df['Thyroid_Cancer_Risk'], palette="coolwarm")

plt.title("Scatter Plot of TSH Level vs Nodule Size (Subset of 200 Records)")  
plt.xlabel("TSH Level")  
plt.ylabel("Nodule Size")  

plt.show()

# %% [markdown]
# # Heatmap

# %%
subset_df = df.head(200)

correlation_matrix = subset_df[['Age', 'TSH_Level', 'T3_Level', 'T4_Level', 'Nodule_Size']].corr()

plt.figure(figsize=(6, 4))  
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=1)

plt.title("Correlation Heatmap (Subset of 200 Records)")  
plt.show()

# %% [markdown]
# # Box Plot:TSH Level vs Thyroid Cancer Risk

# %%
plt.figure(figsize=(8, 5))  
sns.set(style='dark')  
sns.boxplot(x=subset_df['Thyroid_Cancer_Risk'], y=subset_df['TSH_Level'], palette="coolwarm")

plt.title("TSH Level Distribution Across Cancer Risk Levels (Subset of 200)")
plt.xlabel("Thyroid Cancer Risk")  
plt.ylabel("TSH Level")  

plt.show()

# %%
#Countplot
subset_df = df.head(200)

plt.figure(figsize=(5, 6))  
sns.set(style='dark')  

sns.countplot(x='Thyroid_Cancer_Risk', data=subset_df, palette="coolwarm")

plt.title("Count of Thyroid Cancer Risk Levels (Subset of 200)")  
plt.xlabel("Thyroid Cancer Risk")  
plt.ylabel("Count")  

plt.show()

# %% [markdown]
# # Linechart

# %%
subset_df = df.head(200)

plt.figure(figsize=(8, 5))  
sns.set(style='dark')  
sns.lineplot(x=subset_df['Age'], y=subset_df['TSH_Level'], marker='o', color='b')

plt.title("TSH Levels Over Age (Subset of 200)")  
plt.xlabel("Age")  
plt.ylabel("TSH Level") 

plt.show()

# %% [markdown]
# # Piechart

# %%
risk_counts = subset_df['Thyroid_Cancer_Risk'].value_counts()

plt.figure(figsize=(6, 6)) 
colors = ['lightblue', 'lightcoral', 'lightgreen']  
plt.pie(risk_counts, labels=risk_counts.index, autopct='%1.1f%%', colors=colors, startangle=90)
plt.title("Thyroid Cancer Risk Distribution (Subset of 200)")  
plt.show()
